# %%
import numpy as np
from astropy.io import fits
from astropy.table import Table
from matplotlib.colors import LogNorm
import scipy
from scipy import stats

import matplotlib.pyplot as plt

# %%
plt.scatter([1], [1], color='red', s=6)
